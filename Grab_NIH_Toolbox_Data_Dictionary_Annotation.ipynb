# %% [markdown]
# Get NIH Toolbox data dictionary items and merge with Crosswalk

# %%
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile


#read crosswalkfile
pathin="/home/petra/UbWinSharedSpace1/ccf-nda-behavioral/PycharmToolbox/Ipad2NDA_withCrosswalk/NIHToolbox2NDA/"
crosswalkfile="Crosswalk_NIH_Toolbox_2_NDA.csv"
crosswalk=pd.read_csv(pathin+crosswalkfile,header=0,low_memory=False, encoding = "ISO-8859-1")


#readfromNIH='https://nihtoolbox.desk.com/customer/portal/kb_article_attachments/144125/original.xlsx?1562788410'
#in the meantime, read from a downloaded copy (replace the paths below with your own locations):
fpath_downloadedNIH='/home/petra/UbWinSharedSpace1/ccf-nda-behavioral/PycharmToolbox/Ipad2NDA_withCrosswalk/NIHToolbox2NDA/'
fname='NIH_Toolbox_IPAD_DataDictionary041119_Edited_070919_interpretted.xlsx'
fstring=fpath_downloadedNIH+fname
tlbxitems = pd.read_excel(fstring, sheet_name='NIH Toolbox')

# %%
crosswalk.columns
# Out:
# Index(['Measurement System', 'Domain', 'Inst', 'Item ID', 'Stem', 'Context',
#        'DataType', 'Responses', 'Translation (output of IPAD)',
#        'action_requested', 'requested_python', 'specialty_code',
#        'hcp_variable', 'hcp_variable_upload', 'nda_structure', 'nda_element',
#        'description', 'valueRange', 'notes', 'template', 'inst_short',
#        'Source'],
#       dtype='object')

# %%
tlbxitems.columns
# Out:
# Index(['Measurement System', 'Domain', 'Instrument Title', 'Item ID', 'Stem',
#        'Context', 'DataType', 'Responses', 'Translation (output of IPAD)'],
#       dtype='object')

# %%
tlbxitems['hcp_variable']=tlbxitems['Item ID'].str.lower().str.replace('-','_').str.replace('(','_').str.replace(')','_')
tlbxitems=tlbxitems.rename(columns={'Instrument Title':'Inst'})

# %%
tlbxitems.columns
# Out:
# Index(['Measurement System', 'Domain', 'Inst', 'Item ID', 'Stem', 'Context',
#        'DataType', 'Responses', 'Translation (output of IPAD)',
#        'hcp_variable'],
#       dtype='object')

# %%
#always pull the latest annotation from the NIH Toolbox Data dictionary...i.e. drop the columns corresponding to this information from the crosswalk
#which was only holding them there for convenience sake.
newcrosswalk=pd.merge(tlbxitems,crosswalk.drop(columns=['Measurement System', 'Domain', 'Item ID', 'Stem', 'Context',
       'DataType', 'Responses', 'Translation (output of IPAD)']),how='right',on=['Inst','hcp_variable'])

# %%
newcrosswalk
# Out:
#      Measurement System     Domain  \
# 0           NIH Toolbox  Cognition
# 1           NIH Toolbox  Cognition
# 2           NIH Toolbox  Cognition
# 3           NIH Toolbox  Cognition
# 4           NIH Toolbox  Cognition
# 5           NIH Toolbox  Cognition
# 6           NIH Toolbox  Cognition
# 7           NIH Toolbox  Cognition
# 8           NIH Toolbox  Cognition
# 9           NIH Toolbox  Cognition
# 10          NIH Toolbox  Cognition
# 11          NIH Toolbox  Cognition
# 12          NIH Toolbox  Cognition
# 13          NIH Toolbox  Cognition
# 14          NIH Toolbox  Cognition
# 15          NIH Toolbox  Cognition
# 16          NIH Toolbox  Cognition
# 17          NIH Toolbox  Cognition
# 18          NIH Toolbox  Cognition
# 19          NIH Toolbox  Cognition
# 20          NIH Toolbox  Cognition
# 21          NIH Toolbox  Cognition
# 22          NIH Toolbox  Cognition
# 23          NIH Toolbox  Cognition
# 24          NIH Toolbox  Cognition
# 25          NIH Toolbox  Cognition
# 26          NIH Toolbox  Cognition
# 27          NIH Toolbox  Cognition
# 28          NIH Toolbox  Cognition
# 29          NIH Toolbox  Cognition
# ...                 ...        ...
# 2984                NaN        NaN
# 2985                NaN        NaN
# 2986                NaN        NaN
# 2987                NaN        NaN
# 2988                NaN        NaN
# 2989                NaN        NaN
# 2990                NaN        NaN
# 2991                NaN        NaN
# 2992                NaN        NaN
# 2993                NaN        NaN
# 2994                NaN        NaN
# 2995                NaN        NaN
# 2996                NaN        NaN
# 2997                NaN        NaN
# 2998                NaN        NaN
# 2999                NaN        NaN
# 3000                NaN        NaN
# 3001                NaN        NaN
# 3002                NaN        NaN
# 3003                NaN        NaN
# 3004                NaN        NaN
# 3005                NaN        NaN
# 3006                NaN        NaN
# 3007                NaN        NaN
# 3008                NaN        NaN
# 3009                NaN        NaN
# 3010                NaN        NaN
# 3011                NaN        NaN
# 3012                NaN        NaN
# 3013                NaN        NaN
#
#                                                    Inst   Item ID      Stem  \
# 0       NIH Toolbox Picture Vocabulary Test Age 3+ v2.0  LAVOC188  LAVOC188
# 1       NIH Toolbox Picture Vocabulary Test Age 3+ v2.0  LAVOC189  LAVOC189
# 2       NIH Toolbox Picture Vocabulary Test Age 3+ v2.0  LAVOC330  LAVOC330
# 3       NIH Toolbox Picture Vocabulary Test Age 3+ v2.0  LAVOC120  LAVOC120
# 4       NIH Toolbox Picture Vocabulary Test Age 3+ v2.0  LAVOC259  LAVOC259
# 5       NIH Toolbox Picture Vocabulary Test Age 3+ v2.0  LAVOC191  LAVOC191
# 6       NIH Toolbox Picture Vocabulary Test Age 3+ v2.0  LAVOC190  LAVOC190
# 7       NIH Toolbox Picture Vocabulary Test Age 3+ v2.0  LAVOC452  LAVOC452
# 8       NIH Toolbox Picture Vocabulary Test Age 3+ v2.0  LAVOC320  LAVOC320
# 9       NIH Toolbox Picture Vocabulary Test Age 3+ v2.0  LAVOC242  LAVOC242
# 10      NIH Toolbox Picture Vocabulary Test Age 3+ v2.0  LAVOC161  LAVOC161
# 11      NIH Toolbox Picture Vocabulary Test Age 3+ v2.0  LAVOC091  LAVOC091
# 12      NIH Toolbox Picture Vocabulary Test Age 3+ v2.0  LAVOC155  LAVOC155
# 13      NIH Toolbox Picture Vocabulary Test Age 3+ v2.0  LAVOC206  LAVOC206
# 14      NIH Toolbox Picture Vocabulary Test Age 3+ v2.0  LAVOC199  LAVOC199
# 15      NIH Toolbox Picture Vocabulary Test Age 3+ v2.0  LAVOC260  LAVOC260
# 16      NIH Toolbox Picture Vocabulary Test Age 3+ v2.0  LAVOC237  LAVOC237
# 17      NIH Toolbox Picture Vocabulary Test Age 3+ v2.0  LAVOC364  LAVOC364
# 18      NIH Toolbox Picture Vocabulary Test Age 3+ v2.0  LAVOC257  LAVOC257
# 19      NIH Toolbox Picture Vocabulary Test Age 3+ v2.0  LAVOC263  LAVOC263
# 20      NIH Toolbox Picture Vocabulary Test Age 3+ v2.0  LAVOC241  LAVOC241
# 21      NIH Toolbox Picture Vocabulary Test Age 3+ v2.0  LAVOC145  LAVOC145
# 22      NIH Toolbox Picture Vocabulary Test Age 3+ v2.0  LAVOC194  LAVOC194
# 23      NIH Toolbox Picture Vocabulary Test Age 3+ v2.0  LAVOC303  LAVOC303
# 24      NIH Toolbox Picture Vocabulary Test Age 3+ v2.0  LAVOC215  LAVOC215
# 25      NIH Toolbox Picture Vocabulary Test Age 3+ v2.0  LAVOC422  LAVOC422
# 26      NIH Toolbox Picture Vocabulary Test Age 3+ v2.0  LAVOC226  LAVOC226
# 27      NIH Toolbox Picture Vocabulary Test Age 3+ v2.0  LAVOC222  LAVOC222
# 28      NIH Toolbox Picture Vocabulary Test Age 3+ v2.0  LAVOC214  LAVOC214
# 29      NIH Toolbox Picture Vocabulary Test Age 3+ v2.0  LAVOC203  LAVOC203
# ...                                                 ...       ...       ...
# 2984  NIH Toolbox Oral Reading Recognition Test Age ...       NaN       NaN
# 2985  NIH Toolbox Oral Reading Recognition Test Age ...       NaN       NaN
# 2986  NIH Toolbox Oral Reading Recognition Test Age ...       NaN       NaN
# 2987  NIH Toolbox Oral Reading Recognition Test Age ...       NaN       NaN
# 2988  NIH Toolbox Oral Reading Recognition Test Age ...       NaN       NaN
# 2989  NIH Toolbox Oral Reading Recognition Test Age ...       NaN       NaN
# 2990  NIH Toolbox Oral Reading Recognition Test Age ...       NaN       NaN
# 2991  NIH Toolbox Oral Reading Recognition Test Age ...       NaN       NaN
# 2992  NIH Toolbox Oral Reading Recognition Test Age ...       NaN       NaN
# 2993  NIH Toolbox Oral Reading Recognition Test Age ...       NaN       NaN
# 2994  NIH Toolbox Oral Reading Recognition Test Age ...       NaN       NaN
# 2995  NIH Toolbox Oral Reading Recognition Test Age ...       NaN       NaN
# 2996  NIH Toolbox Oral Reading Recognition Test Age ...       NaN       NaN
# 2997  NIH Toolbox Oral Reading Recognition Test Age ...       NaN       NaN
# 2998  NIH Toolbox Oral Reading Recognition Test Age ...       NaN       NaN
# 2999  NIH Toolbox Oral Reading Recognition Test Age ...       NaN       NaN
# 3000  NIH Toolbox Oral Reading Recognition Test Age ...       NaN       NaN
# 3001  NIH Toolbox Oral Reading Recognition Test Age ...       NaN       NaN
# 3002  NIH Toolbox Oral Reading Recognition Test Age ...       NaN       NaN
# 3003  NIH Toolbox Oral Reading Recognition Test Age ...       NaN       NaN
# 3004  NIH Toolbox Oral Reading Recognition Test Age ...       NaN       NaN
# 3005  NIH Toolbox Oral Reading Recognition Test Age ...       NaN       NaN
# 3006  NIH Toolbox Oral Reading Recognition Test Age ...       NaN       NaN
# 3007  NIH Toolbox Oral Reading Recognition Test Age ...       NaN       NaN
# 3008  NIH Toolbox Oral Reading Recognition Test Age ...       NaN       NaN
# 3009  NIH Toolbox Oral Reading Recognition Test Age ...       NaN       NaN
# 3010  NIH Toolbox Oral Reading Recognition Test Age ...       NaN       NaN
# 3011  NIH Toolbox Oral Reading Recognition Test Age ...       NaN       NaN
# 3012  NIH Toolbox Oral Reading Recognition Test Age ...       NaN       NaN
# 3013  NIH Toolbox Oral Reading Recognition Test Age ...       NaN       NaN
#
#      Context DataType                                          Responses  \
# 0        NaN  integer  0=LAVOC188-1\n0=LAVOC188-2\n1=LAVOC188-9\n0=LA...
# 1        NaN  integer  1=LAVOC189-9\n0=LAVOC189-3\n0=LAVOC189-2\n0=LA...
# 2        NaN  integer  0=LAVOC330-1\n1=LAVOC330-9\n0=LAVOC330-3\n0=LA...
# 3        NaN  integer  0=LAVOC120-2\n0=LAVOC120-3\n1=LAVOC120-9\n0=LA...
# 4        NaN  integer  0=LAVOC259-3\n0=LAVOC259-2\n0=LAVOC259-1\n1=LA...
# 5        NaN  integer  0=LAVOC191-3\n0=LAVOC191-2\n1=LAVOC191-9\n0=LA...
# 6        NaN  integer  0=LAVOC190-2\n0=LAVOC190-1\n0=LAVOC190-3\n1=LA...
# 7        NaN  integer  0=LAVOC452-1\n0=LAVOC452-2\n0=LAVOC452-3\n1=LA...
# 8        NaN  integer  0=LAVOC320-2\n0=LAVOC320-1\n0=LAVOC320-3\n1=LA...
# 9        NaN  integer  0=LAVOC242-3\n0=LAVOC242-2\n1=LAVOC242-9\n0=LA...
# 10       NaN  integer  0=LAVOC161-3\n0=LAVOC161-2\n0=LAVOC161-1\n1=LA...
# 11       NaN  integer  0=LAVOC091-2\n1=LAVOC091-9\n0=LAVOC091-3\n0=LA...
# 12       NaN  integer  0=LAVOC155-1\n1=LAVOC155-9\n0=LAVOC155-3\n0=LA...
# 13       NaN  integer  0=LAVOC206-3\n1=LAVOC206-9\n0=LAVOC206-1\n0=LA...
# 14       NaN  integer  0=LAVOC199-3\n0=LAVOC199-2\n0=LAVOC199-1\n1=LA...
# 15       NaN  integer  0=LAVOC260-2\n0=LAVOC260-1\n1=LAVOC260-9\n0=LA...
# 16       NaN  integer  0=LAVOC237-2\n1=LAVOC237-9\n0=LAVOC237-3\n0=LA...
# 17       NaN  integer  0=LAVOC364-3\n0=LAVOC364-2\n0=LAVOC364-1\n1=LA...
# 18       NaN  integer  0=LAVOC257-2\n1=LAVOC257-9\n0=LAVOC257-3\n0=LA...
# 19       NaN  integer  0=LAVOC263-3\n0=LAVOC263-2\n0=LAVOC263-1\n1=LA...
# 20       NaN  integer  1=LAVOC241-9\n0=LAVOC241-3\n0=LAVOC241-2\n0=LA...
# 21       NaN  integer  0=LAVOC145-3\n1=LAVOC145-9\n0=LAVOC145-1\n0=LA...
# 22       NaN  integer  1=LAVOC194-9\n0=LAVOC194-2\n0=LAVOC194-3\n0=LA...
# 23       NaN  integer  0=LAVOC303-1\n1=LAVOC303-9\n0=LAVOC303-3\n0=LA...
# 24       NaN  integer  0=LAVOC215-1\n0=LAVOC215-2\n1=LAVOC215-9\n0=LA...
# 25       NaN  integer  0=LAVOC422-2\n0=LAVOC422-1\n0=LAVOC422-3\n1=LA...
# 26       NaN  integer  0=LAVOC226-1\n0=LAVOC226-3\n0=LAVOC226-2\n1=LA...
# 27       NaN  integer  0=LAVOC222-3\n0=LAVOC222-2\n0=LAVOC222-1\n1=LA...
# 28       NaN  integer  1=LAVOC214-9\n0=LAVOC214-3\n0=LAVOC214-2\n0=LA...
# 29       NaN  integer  0=LAVOC203-2\n1=LAVOC203-9\n0=LAVOC203-3\n0=LA...
# ...      ...      ...                                                ...
# 2984     NaN      NaN                                                NaN
# 2985     NaN      NaN                                                NaN
# 2986     NaN      NaN                                                NaN
# 2987     NaN      NaN                                                NaN
# 2988     NaN      NaN                                                NaN
# 2989     NaN      NaN                                                NaN
# 2990     NaN      NaN                                                NaN
# 2991     NaN      NaN                                                NaN
# 2992     NaN      NaN                                                NaN
# 2993     NaN      NaN                                                NaN
# 2994     NaN      NaN                                                NaN
# 2995     NaN      NaN                                                NaN
# 2996     NaN      NaN                                                NaN
# 2997     NaN      NaN                                                NaN
# 2998     NaN      NaN                                                NaN
# 2999     NaN      NaN                                                NaN
# 3000     NaN      NaN                                                NaN
# 3001     NaN      NaN                                                NaN
# 3002     NaN      NaN                                                NaN
# 3003     NaN      NaN                                                NaN
# 3004     NaN      NaN                                                NaN
# 3005     NaN      NaN                                                NaN
# 3006     NaN      NaN                                                NaN
# 3007     NaN      NaN                                                NaN
# 3008     NaN      NaN                                                NaN
# 3009     NaN      NaN                                                NaN
# 3010     NaN      NaN                                                NaN
# 3011     NaN      NaN                                                NaN
# 3012     NaN      NaN                                                NaN
# 3013     NaN      NaN                                                NaN
#
#       Translation (output of IPAD)                        hcp_variable  ...  \
# 0                              NaN                            lavoc188  ...
# 1                              NaN                            lavoc189  ...
# 2                              NaN                            lavoc330  ...
# 3                              NaN                            lavoc120  ...
# 4                              NaN                            lavoc259  ...
# 5                              NaN                            lavoc191  ...
# 6                              NaN                            lavoc190  ...
# 7                              NaN                            lavoc452  ...
# 8                              NaN                            lavoc320  ...
# 9                              NaN                            lavoc242  ...
# 10                             NaN                            lavoc161  ...
# 11                             NaN                            lavoc091  ...
# 12                             NaN                            lavoc155  ...
# 13                             NaN                            lavoc206  ...
# 14                             NaN                            lavoc199  ...
# 15                             NaN                            lavoc260  ...
# 16                             NaN                            lavoc237  ...
# 17                             NaN                            lavoc364  ...
# 18                             NaN                            lavoc257  ...
# 19                             NaN                            lavoc263  ...
# 20                             NaN                            lavoc241  ...
# 21                             NaN                            lavoc145  ...
# 22                             NaN                            lavoc194  ...
# 23                             NaN                            lavoc303  ...
# 24                             NaN                            lavoc215  ...
# 25                             NaN                            lavoc422  ...
# 26                             NaN                            lavoc226  ...
# 27                             NaN                            lavoc222  ...
# 28                             NaN                            lavoc214  ...
# 29                             NaN                            lavoc203  ...
# ...                            ...                                 ...  ...
# 2984                           NaN                             lare267  ...
# 2985                           NaN                             lare268  ...
# 2986                           NaN                             lare269  ...
# 2987                           NaN                             lare270  ...
# 2988                           NaN                             lare271  ...
# 2989                           NaN                             lare272  ...
# 2990                           NaN                             lare273  ...
# 2991                           NaN                             lare274  ...
# 2992                           NaN                             lare275  ...
# 2993                           NaN                             lare276  ...
# 2994                           NaN                             lare277  ...
# 2995                           NaN                             lare278  ...
# 2996                           NaN                             lare279  ...
# 2997                           NaN                             lare280  ...
# 2998                           NaN                             larebr2  ...
# 2999                           NaN                             larebr4  ...
# 3000                           NaN                             larebr5  ...
# 3001                           NaN                             larebr7  ...
# 3002                           NaN                           laresc001  ...
# 3003                           NaN                           laresc002  ...
# 3004                           NaN                           laresc004  ...
# 3005                           NaN                           laresc005  ...
# 3006                           NaN                           laresc006  ...
# 3007                           NaN                           laresc007  ...
# 3008                           NaN                           laresc008  ...
# 3009                           NaN                           laresc009  ...
# 3010                           NaN  National_Percentile__age_adjusted_  ...
# 3011                           NaN                                  SE  ...
# 3012                           NaN                               Theta  ...
# 3013                           NaN          Uncorrected_Standard_Score  ...
#
#                                          specialty_code  \
# 0                                        button convert
# 1                                        button convert
# 2                                        button convert
# 3                                        button convert
# 4                                        button convert
# 5                                        button convert
# 6                                        button convert
# 7                                        button convert
# 8                                        button convert
# 9                                        button convert
# 10                                       button convert
# 11                                       button convert
# 12                                       button convert
# 13                                       button convert
# 14                                       button convert
# 15                                       button convert
# 16                                       button convert
# 17                                       button convert
# 18                                       button convert
# 19                                       button convert
# 20                                       button convert
# 21                                       button convert
# 22                                       button convert
# 23                                       button convert
# 24                                       button convert
# 25                                       button convert
# 26                                       button convert
# 27                                       button convert
# 28                                       button convert
# 29                                       button convert
# ...                                                 ...
# 2984  Instrument not in published NIH Toolbox Data D...
# 2985  Instrument not in published NIH Toolbox Data D...
# 2986  Instrument not in published NIH Toolbox Data D...
# 2987  Instrument not in published NIH Toolbox Data D...
# 2988  Instrument not in published NIH Toolbox Data D...
# 2989  Instrument not in published NIH Toolbox Data D...
# 2990  Instrument not in published NIH Toolbox Data D...
# 2991  Instrument not in published NIH Toolbox Data D...
# 2992  Instrument not in published NIH Toolbox Data D...
# 2993  Instrument not in published NIH Toolbox Data D...
# 2994  Instrument not in published NIH Toolbox Data D...
# 2995  Instrument not in published NIH Toolbox Data D...
# 2996  Instrument not in published NIH Toolbox Data D...
# 2997  Instrument not in published NIH Toolbox Data D...
# 2998  Instrument not in published NIH Toolbox Data D...
# 2999  Instrument not in published NIH Toolbox Data D...
# 3000  Instrument not in published NIH Toolbox Data D...
# 3001  Instrument not in published NIH Toolbox Data D...
# 3002  Instrument not in published NIH Toolbox Data D...
# 3003  Instrument not in published NIH Toolbox Data D...
# 3004  Instrument not in published NIH Toolbox Data D...
# 3005  Instrument not in published NIH Toolbox Data D...
# 3006  Instrument not in published NIH Toolbox Data D...
# 3007  Instrument not in published NIH Toolbox Data D...
# 3008  Instrument not in published NIH Toolbox Data D...
# 3009  Instrument not in published NIH Toolbox Data D...
# 3010  Instrument not in published NIH Toolbox Data D...
# 3011  Instrument not in published NIH Toolbox Data D...
# 3012  Instrument not in published NIH Toolbox Data D...
# 3013  Instrument not in published NIH Toolbox Data D...
#
#                      hcp_variable_upload nda_structure        nda_element  \
# 0                               lavoc188        tpvt01           lavoc188
# 1                               lavoc189        tpvt01           lavoc189
# 2                               lavoc330        tpvt01           lavoc330
# 3                               lavoc120        tpvt01           lavoc120
# 4                               lavoc259        tpvt01           lavoc259
# 5                               lavoc191        tpvt01           lavoc191
# 6                               lavoc190        tpvt01           lavoc190
# 7                               lavoc452        tpvt01           lavoc452
# 8                               lavoc320        tpvt01           lavoc320
# 9                               lavoc242        tpvt01           lavoc242
# 10                              lavoc161        tpvt01           lavoc161
# 11                              lavoc091        tpvt01           lavoc091
# 12                              lavoc155        tpvt01           lavoc155
# 13                              lavoc206        tpvt01           lavoc206
# 14                              lavoc199        tpvt01           lavoc199
# 15                              lavoc260        tpvt01           lavoc260
# 16                              lavoc237        tpvt01           lavoc237
# 17                              lavoc364        tpvt01           lavoc364
# 18                              lavoc257        tpvt01           lavoc257
# 19                              lavoc263        tpvt01           lavoc263
# 20                              lavoc241        tpvt01           lavoc241
# 21                              lavoc145        tpvt01           lavoc145
# 22                              lavoc194        tpvt01           lavoc194
# 23                              lavoc303        tpvt01           lavoc303
# 24                              lavoc215        tpvt01           lavoc215
# 25                              lavoc422        tpvt01           lavoc422
# 26                              lavoc226        tpvt01           lavoc226
# 27                              lavoc222        tpvt01           lavoc222
# 28                              lavoc214        tpvt01           lavoc214
# 29                              lavoc203        tpvt01           lavoc203
# ...                                  ...           ...                ...
# 2984                             lare267        orrt01            lare267
# 2985                             lare268        orrt01            lare268
# 2986                             lare269        orrt01            lare269
# 2987                             lare270        orrt01            lare270
# 2988                             lare271        orrt01            lare271
# 2989                             lare272        orrt01            lare272
# 2990                             lare273        orrt01            lare273
# 2991                             lare274        orrt01            lare274
# 2992                             lare275        orrt01            lare275
# 2993                             lare276        orrt01            lare276
# 2994                             lare277        orrt01            lare277
# 2995                             lare278        orrt01            lare278
# 2996                             lare279        orrt01            lare279
# 2997                             lare280        orrt01            lare280
# 2998                             larebr2        orrt01            larebr2
# 2999                             larebr4        orrt01            larebr4
# 3000                             larebr5        orrt01            larebr5
# 3001                             larebr7        orrt01            larebr7
# 3002                           laresc001        orrt01          laresc001
# 3003                           laresc002        orrt01          laresc002
# 3004                           laresc004        orrt01          laresc004
# 3005                           laresc005        orrt01          laresc005
# 3006                           laresc006        orrt01          laresc006
# 3007                           laresc007        orrt01          laresc007
# 3008                           laresc008        orrt01          laresc008
# 3009                           laresc009        orrt01          laresc009
# 3010  National_Percentile__age_adjusted_        orrt01          read_perc
# 3011                                  SE        orrt01        nih_tlbx_se
# 3012                               Theta        orrt01     nih_tlbx_theta
# 3013          Uncorrected_Standard_Score        orrt01  tbx_reading_score
#
#                                description valueRange                   notes  \
# 0              Picture Vocabulary Item 188        0;1  0=Incorrect; 1=Correct
# 1              Picture Vocabulary Item 189        0;1  0=Incorrect; 1=Correct
# 2              Picture Vocabulary Item 330        0;1  0=Incorrect; 1=Correct
# 3              Picture Vocabulary Item 120        0;1  0=Incorrect; 1=Correct
# 4              Picture Vocabulary Item 259        0;1  0=Incorrect; 1=Correct
# 5              Picture Vocabulary Item 191        0;1  0=Incorrect; 1=Correct
# 6              Picture Vocabulary Item 190        0;1  0=Incorrect; 1=Correct
# 7              Picture Vocabulary Item 452        0;1  0=Incorrect; 1=Correct
# 8              Picture Vocabulary Item 320        0;1  0=Incorrect; 1=Correct
# 9              Picture Vocabulary Item 242        0;1  0=Incorrect; 1=Correct
# 10             Picture Vocabulary Item 161        0;1  0=Incorrect; 1=Correct
# 11             Picture Vocabulary Item 091        0;1  0=Incorrect; 1=Correct
# 12             Picture Vocabulary Item 155        0;1  0=Incorrect; 1=Correct
# 13             Picture Vocabulary Item 206        0;1  0=Incorrect; 1=Correct
# 14             Picture Vocabulary Item 199        0;1  0=Incorrect; 1=Correct
# 15             Picture Vocabulary Item 260        0;1  0=Incorrect; 1=Correct
# 16             Picture Vocabulary Item 237        0;1  0=Incorrect; 1=Correct
# 17             Picture Vocabulary Item 364        0;1  0=Incorrect; 1=Correct
# 18             Picture Vocabulary Item 257        0;1  0=Incorrect; 1=Correct
# 19             Picture Vocabulary Item 263        0;1  0=Incorrect; 1=Correct
# 20             Picture Vocabulary Item 241        0;1  0=Incorrect; 1=Correct
# 21             Picture Vocabulary Item 145        0;1  0=Incorrect; 1=Correct
# 22             Picture Vocabulary Item 194        0;1  0=Incorrect; 1=Correct
# 23             Picture Vocabulary Item 303        0;1  0=Incorrect; 1=Correct
# 24             Picture Vocabulary Item 215        0;1  0=Incorrect; 1=Correct
# 25             Picture Vocabulary Item 422        0;1  0=Incorrect; 1=Correct
# 26             Picture Vocabulary Item 226        0;1  0=Incorrect; 1=Correct
# 27             Picture Vocabulary Item 222        0;1  0=Incorrect; 1=Correct
# 28             Picture Vocabulary Item 214        0;1  0=Incorrect; 1=Correct
# 29             Picture Vocabulary Item 203        0;1  0=Incorrect; 1=Correct
# ...                                    ...        ...                     ...
# 2984    Oral Reading Recognition Item  267        0;1  0=Incorrect; 1=Correct
# 2985    Oral Reading Recognition Item  268        0;1  0=Incorrect; 1=Correct
# 2986    Oral Reading Recognition Item  269        0;1  0=Incorrect; 1=Correct
# 2987    Oral Reading Recognition Item  270        0;1  0=Incorrect; 1=Correct
# 2988    Oral Reading Recognition Item  271        0;1  0=Incorrect; 1=Correct
# 2989    Oral Reading Recognition Item  272        0;1  0=Incorrect; 1=Correct
# 2990    Oral Reading Recognition Item  273        0;1  0=Incorrect; 1=Correct
# 2991    Oral Reading Recognition Item  274        0;1  0=Incorrect; 1=Correct
# 2992    Oral Reading Recognition Item  275        0;1  0=Incorrect; 1=Correct
# 2993    Oral Reading Recognition Item  276        0;1  0=Incorrect; 1=Correct
# 2994    Oral Reading Recognition Item  277        0;1  0=Incorrect; 1=Correct
# 2995    Oral Reading Recognition Item  278        0;1  0=Incorrect; 1=Correct
# 2996    Oral Reading Recognition Item  279        0;1  0=Incorrect; 1=Correct
# 2997    Oral Reading Recognition Item  280        0;1  0=Incorrect; 1=Correct
# 2998    Oral Reading Recognition Item  BR2        0;1  0=Incorrect; 1=Correct
# 2999    Oral Reading Recognition Item  BR4        0;1  0=Incorrect; 1=Correct
# 3000    Oral Reading Recognition Item  BR5        0;1  0=Incorrect; 1=Correct
# 3001    Oral Reading Recognition Item  BR7        0;1  0=Incorrect; 1=Correct
# 3002  Oral Reading Recognition Item  SC001        0;1  0=Incorrect; 1=Correct
# 3003  Oral Reading Recognition Item  SC002        0;1  0=Incorrect; 1=Correct
# 3004  Oral Reading Recognition Item  SC004        0;1  0=Incorrect; 1=Correct
# 3005  Oral Reading Recognition Item  SC005        0;1  0=Incorrect; 1=Correct
# 3006  Oral Reading Recognition Item  SC006        0;1  0=Incorrect; 1=Correct
# 3007  Oral Reading Recognition Item  SC007        0;1  0=Incorrect; 1=Correct
# 3008  Oral Reading Recognition Item  SC008        0;1  0=Incorrect; 1=Correct
# 3009  Oral Reading Recognition Item  SC009        0;1  0=Incorrect; 1=Correct
# 3010              Reading test  Percentile        NaN                     NaN
# 3011                        Standard Error        NaN       999=NA/NK/missing
# 3012                                 Theta        NaN       999=NA/NK/missing
# 3013                    Reading test score        NaN                     NaN
#
#                            template inst_short     Source
# 0     TPVT_v2.0.tpvt01_template.csv  TPVT_v2.0  HCPD HCPA
# 1     TPVT_v2.0.tpvt01_template.csv  TPVT_v2.0       HCPD
# 2     TPVT_v2.0.tpvt01_template.csv  TPVT_v2.0       HCPD
# 3     TPVT_v2.0.tpvt01_template.csv  TPVT_v2.0       HCPD
# 4     TPVT_v2.0.tpvt01_template.csv  TPVT_v2.0       HCPD
# 5     TPVT_v2.0.tpvt01_template.csv  TPVT_v2.0  HCPD HCPA
# 6     TPVT_v2.0.tpvt01_template.csv  TPVT_v2.0       HCPD
# 7     TPVT_v2.0.tpvt01_template.csv  TPVT_v2.0       HCPD
# 8     TPVT_v2.0.tpvt01_template.csv  TPVT_v2.0  HCPD HCPA
# 9     TPVT_v2.0.tpvt01_template.csv  TPVT_v2.0       HCPD
# 10    TPVT_v2.0.tpvt01_template.csv  TPVT_v2.0  HCPD HCPA
# 11    TPVT_v2.0.tpvt01_template.csv  TPVT_v2.0       HCPD
# 12    TPVT_v2.0.tpvt01_template.csv  TPVT_v2.0  HCPD HCPA
# 13    TPVT_v2.0.tpvt01_template.csv  TPVT_v2.0  HCPD HCPA
# 14    TPVT_v2.0.tpvt01_template.csv  TPVT_v2.0       HCPD
# 15    TPVT_v2.0.tpvt01_template.csv  TPVT_v2.0       HCPD
# 16    TPVT_v2.0.tpvt01_template.csv  TPVT_v2.0       HCPD
# 17    TPVT_v2.0.tpvt01_template.csv  TPVT_v2.0       HCPD
# 18    TPVT_v2.0.tpvt01_template.csv  TPVT_v2.0  HCPD HCPA
# 19    TPVT_v2.0.tpvt01_template.csv  TPVT_v2.0  HCPD HCPA
# 20    TPVT_v2.0.tpvt01_template.csv  TPVT_v2.0  HCPD HCPA
# 21    TPVT_v2.0.tpvt01_template.csv  TPVT_v2.0  HCPD HCPA
# 22    TPVT_v2.0.tpvt01_template.csv  TPVT_v2.0       HCPD
# 23    TPVT_v2.0.tpvt01_template.csv  TPVT_v2.0       HCPD
# 24    TPVT_v2.0.tpvt01_template.csv  TPVT_v2.0  HCPD HCPA
# 25    TPVT_v2.0.tpvt01_template.csv  TPVT_v2.0       HCPD
# 26    TPVT_v2.0.tpvt01_template.csv  TPVT_v2.0  HCPD HCPA
# 27    TPVT_v2.0.tpvt01_template.csv  TPVT_v2.0  HCPD HCPA
# 28    TPVT_v2.0.tpvt01_template.csv  TPVT_v2.0  HCPD HCPA
# 29    TPVT_v2.0.tpvt01_template.csv  TPVT_v2.0  HCPD HCPA
# ...                             ...        ...        ...
# 2984  ORRT_v2.1_orrt01_template.csv  ORRT_v2.1  HCPD HCPA
# 2985  ORRT_v2.1_orrt01_template.csv  ORRT_v2.1  HCPD HCPA
# 2986  ORRT_v2.1_orrt01_template.csv  ORRT_v2.1  HCPD HCPA
# 2987   ORRT_2.1_orrt01_template.csv   ORRT_2.1       HCPA
# 2988  ORRT_v2.1_orrt01_template.csv  ORRT_v2.1  HCPD HCPA
# 2989   ORRT_2.1_orrt01_template.csv   ORRT_2.1       HCPA
# 2990  ORRT_v2.1_orrt01_template.csv  ORRT_v2.1  HCPD HCPA
# 2991   ORRT_2.1_orrt01_template.csv   ORRT_2.1       HCPA
# 2992  ORRT_v2.1_orrt01_template.csv  ORRT_v2.1  HCPD HCPA
# 2993  ORRT_v2.1_orrt01_template.csv  ORRT_v2.1  HCPD HCPA
# 2994  ORRT_v2.1_orrt01_template.csv  ORRT_v2.1  HCPD HCPA
# 2995  ORRT_v2.1_orrt01_template.csv  ORRT_v2.1  HCPD HCPA
# 2996  ORRT_v2.1_orrt01_template.csv  ORRT_v2.1  HCPD HCPA
# 2997   ORRT_2.1_orrt01_template.csv   ORRT_2.1       HCPA
# 2998  ORRT_v2.1_orrt01_template.csv  ORRT_v2.1       HCPD
# 2999  ORRT_v2.1_orrt01_template.csv  ORRT_v2.1       HCPD
# 3000  ORRT_v2.1_orrt01_template.csv  ORRT_v2.1       HCPD
# 3001  ORRT_v2.1_orrt01_template.csv  ORRT_v2.1       HCPD
# 3002  ORRT_v2.1_orrt01_template.csv  ORRT_v2.1       HCPD
# 3003  ORRT_v2.1_orrt01_template.csv  ORRT_v2.1  HCPD HCPA
# 3004   ORRT_2.1_orrt01_template.csv   ORRT_2.1  HCPD HCPA
# 3005   ORRT_2.1_orrt01_template.csv   ORRT_2.1  HCPD HCPA
# 3006   ORRT_2.1_orrt01_template.csv   ORRT_2.1  HCPD HCPA
# 3007   ORRT_2.1_orrt01_template.csv   ORRT_2.1  HCPD HCPA
# 3008   ORRT_2.1_orrt01_template.csv   ORRT_2.1  HCPD HCPA
# 3009   ORRT_2.1_orrt01_template.csv   ORRT_2.1  HCPD HCPA
# 3010   ORRT_2.1_orrt01_template.csv   ORRT_2.1  HCPD HCPA
# 3011   ORRT_2.1_orrt01_template.csv   ORRT_2.1  HCPD HCPA
# 3012   ORRT_2.1_orrt01_template.csv   ORRT_2.1  HCPD HCPA
# 3013   ORRT_2.1_orrt01_template.csv   ORRT_2.1  HCPD HCPA
#
# [3014 rows x 22 columns]

# %%
newcrosswalk.columns
# Out:
# Index(['Measurement System', 'Domain', 'Inst', 'Item ID', 'Stem', 'Context',
#        'DataType', 'Responses', 'Translation (output of IPAD)', 'hcp_variable',
#        'action_requested', 'requested_python', 'specialty_code',
#        'hcp_variable_upload', 'nda_structure', 'nda_element', 'description',
#        'valueRange', 'notes', 'template', 'inst_short', 'Source'],
#       dtype='object')

# %%
newcrosswalk.to_csv(pathin+crosswalkfile,index=False)

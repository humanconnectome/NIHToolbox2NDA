# %% [markdown]
# Get NIH Toolbox data dictionary items and merge with Crosswalk

# %%
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile


#read crosswalkfile
pathin="/home/petra/UbWinSharedSpace1/ccf-nda-behavioral/PycharmToolbox/Ipad2NDA_withCrosswalk/NIHToolbox2NDA/"
crosswalkfile="Crosswalk_NIH_Toolbox_2_NDA.csv"
crosswalk=pd.read_csv(pathin+crosswalkfile,header=0,low_memory=False, encoding = "ISO-8859-1")


#readfromNIH='https://nihtoolbox.desk.com/customer/portal/kb_article_attachments/144125/original.xlsx?1562788410'
#in the meantime, read from a downloaded copy (replace the paths below with your own locations):
fpath_downloadedNIH='/home/petra/UbWinSharedSpace1/ccf-nda-behavioral/PycharmToolbox/Ipad2NDA_withCrosswalk/NIHToolbox2NDA/'
fname='NIH_Toolbox_IPAD_DataDictionary041119_Edited_(7-9-19).xlsx'
fstring=fpath_downloadedNIH+fname
tlbxitems = pd.read_excel(fstring, sheet_name='NIH Toolbox')
#remove indentical duplications from the data dictionary
#vast majority of duplications for variable type 'information' but NOT ALL.  
tlbxitems=tlbxitems.drop_duplicates(subset=None, keep='first', inplace=False).copy()
tlbxitems.shape
# Out:
# (4390, 8)

# %%
crosswalk.shape
# Out:
# (3194, 23)

# %%
crosswalk.columns
# Out:
# Index(['validated', 'Measurement System', 'Domain', 'Item ID', 'Stem',
#        'Context', 'DataType', 'Responses', 'Inst', 'hcp_variable',
#        'action_requested', 'requested_python', 'specialty_code',
#        'hcp_variable_upload', 'nda_structure', 'nda_element', 'template',
#        'inst_short', 'Source', 'description', 'valueRange', 'notes',
#        'nda_structure_link'],
#       dtype='object')

# %%
tlbxitems.columns
# Out:
# Index(['Measurement System', 'Domain', 'Instrument Title', 'Item ID', 'Stem',
#        'Context', 'DataType', 'Responses'],
#       dtype='object')

# %%
tlbxitems['hcp_variable']=tlbxitems['Item ID'].str.lower().str.replace('-','_').str.replace('(','_').str.replace(')','_')
tlbxitems=tlbxitems.rename(columns={'Instrument Title':'Inst'})

# %%
tlbxitems.columns
# Out:
# Index(['Measurement System', 'Domain', 'Inst', 'Item ID', 'Stem', 'Context',
#        'DataType', 'Responses', 'hcp_variable'],
#       dtype='object')

# %%
#always pull the latest annotation from the NIH Toolbox Data dictionary...i.e. drop the columns corresponding to this information from the crosswalk
#which was only holding them there for convenience sake.
newcrosswalk=pd.merge(crosswalk.drop(columns=['Measurement System', 'Domain', 'Item ID', 'Stem', 'Context',
       'DataType', 'Responses']),tlbxitems,how='left',on=['Inst','hcp_variable'])

# %%
newcrosswalk
# Out:
#      validated                                     Inst  \
# 0          NaN      Anxiety Summary Parent Report (3-7)
# 1          NaN      Anxiety Summary Parent Report (3-7)
# 2          NaN      Anxiety Summary Parent Report (3-7)
# 3          NaN      Anxiety Summary Parent Report (3-7)
# 4          NaN      Anxiety Summary Parent Report (3-7)
# 5          NaN      Anxiety Summary Parent Report (3-7)
# 6          NaN      Anxiety Summary Parent Report (3-7)
# 7          NaN      Anxiety Summary Parent Report (3-7)
# 8          NaN      Anxiety Summary Parent Report (3-7)
# 9          NaN      Anxiety Summary Parent Report (3-7)
# 10         NaN               Cognition Composite Scores
# 11         NaN               Cognition Composite Scores
# 12         NaN               Cognition Composite Scores
# 13         NaN               Cognition Composite Scores
# 14         NaN               Cognition Composite Scores
# 15         NaN               Cognition Composite Scores
# 16         NaN               Cognition Composite Scores
# 17         NaN               Cognition Composite Scores
# 18         NaN               Cognition Composite Scores
# 19         NaN               Cognition Composite Scores
# 20         NaN               Cognition Composite Scores
# 21         NaN               Cognition Composite Scores
# 22         NaN               Cognition Composite Scores
# 23         NaN               Cognition Composite Scores
# 24         NaN               Cognition Composite Scores
# 25         NaN               Cognition Composite Scores
# 26         NaN               Cognition Composite Scores
# 27         NaN          Negative Affect Summary (13-17)
# 28         NaN          Negative Affect Summary (13-17)
# 29         NaN          Negative Affect Summary (13-17)
# ...        ...                                      ...
# 3164       NaN   Psychological Well Being Summary (18+)
# 3165       NaN   Psychological Well Being Summary (18+)
# 3166       NaN   Psychological Well Being Summary (18+)
# 3167       NaN   Psychological Well Being Summary (18+)
# 3168       NaN   Psychological Well Being Summary (18+)
# 3169       NaN  Psychological Well Being Summary (8-12)
# 3170       NaN  Psychological Well Being Summary (8-12)
# 3171       NaN  Psychological Well Being Summary (8-12)
# 3172       NaN  Psychological Well Being Summary (8-12)
# 3173       NaN  Psychological Well Being Summary (8-12)
# 3174       NaN  Psychological Well Being Summary (8-12)
# 3175       NaN  Psychological Well Being Summary (8-12)
# 3176       NaN  Psychological Well Being Summary (8-12)
# 3177       NaN  Psychological Well Being Summary (8-12)
# 3178       NaN      Social Satisfaction Summary (13-17)
# 3179       NaN      Social Satisfaction Summary (13-17)
# 3180       NaN      Social Satisfaction Summary (13-17)
# 3181       NaN      Social Satisfaction Summary (13-17)
# 3182       NaN      Social Satisfaction Summary (13-17)
# 3183       NaN      Social Satisfaction Summary (13-17)
# 3184       NaN        Social Satisfaction Summary (18+)
# 3185       NaN        Social Satisfaction Summary (18+)
# 3186       NaN        Social Satisfaction Summary (18+)
# 3187       NaN        Social Satisfaction Summary (18+)
# 3188       NaN        Social Satisfaction Summary (18+)
# 3189       NaN       Social Satisfaction Summary (8-12)
# 3190       NaN       Social Satisfaction Summary (8-12)
# 3191       NaN       Social Satisfaction Summary (8-12)
# 3192       NaN       Social Satisfaction Summary (8-12)
# 3193       NaN       Social Satisfaction Summary (8-12)
#
#                        hcp_variable  \
# 0                       dummy_00095
# 1                       dummy_00096
# 2                       dummy_00097
# 3                       dummy_00098
# 4                       dummy_00099
# 5                              Inst
# 6                   Assessment_Name
# 7                        respondent
# 8           Fully_Corrected_T_score
# 9                          Language
# 10               nih_crystalcogcomp
# 11                    nih_eccogcomp
# 12                 nih_fluidcogcomp
# 13                 nih_totalcogcomp
# 14                         Language
# 15        nih_crystalcogcomp_ageadj
# 16     nih_crystalcogcomp_np_ageadj
# 17    nih_crystalcogcomp_unadjusted
# 18             nih_eccogcomp_ageadj
# 19          nih_eccogcomp_np_ageadj
# 20         nih_eccogcomp_unadjusted
# 21          nih_fluidcogcomp_ageadj
# 22       nih_fluidcogcomp_np_ageadj
# 23      nih_fluidcogcomp_unadjusted
# 24          nih_totalcogcomp_ageadj
# 25       nih_totalcogcomp_np_ageadj
# 26      nih_totalcogcomp_unadjusted
# 27                      dummy_00046
# 28                      dummy_00047
# 29                      dummy_00048
# ...                             ...
# 3164                           Inst
# 3165                Assessment_Name
# 3166                     respondent
# 3167                       Language
# 3168                         TScore
# 3169                    dummy_00091
# 3170                    dummy_00092
# 3171                    dummy_00093
# 3172                    dummy_00094
# 3173                           Inst
# 3174                Assessment_Name
# 3175                     respondent
# 3176        Fully_Corrected_T_score
# 3177                       Language
# 3178                           Inst
# 3179                Assessment_Name
# 3180                     respondent
# 3181        Fully_Corrected_T_score
# 3182                         ItmCnt
# 3183                       Language
# 3184                           Inst
# 3185                Assessment_Name
# 3186                     respondent
# 3187                       Language
# 3188                         TScore
# 3189                           Inst
# 3190                Assessment_Name
# 3191                     respondent
# 3192        Fully_Corrected_T_score
# 3193                       Language
#
#                                        action_requested  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                rename to version_form
# 6     strip 'Assessment' from text, and rename to fn...
# 7                                   rename to comqother
# 8                                                   NaN
# 9     Please rename 'Language' to 'primary_language'...
# 10    had to create this variable from scratch -- se...
# 11    had to create this variable from scratch -- se...
# 12    had to create this variable from scratch -- se...
# 13    had to create this variable from scratch -- se...
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                   set missing to 999
# 22                                   set missing to 999
# 23                                   set missing to 999
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 3164                             rename to version_form
# 3165  strip 'Assessment' from text, and rename to fn...
# 3166                                rename to comqother
# 3167                                                NaN
# 3168                                                NaN
# 3169                                    nih_tlbx_tscore
# 3170                                     nih_tlbx_theta
# 3171                                  nih_tlbx_rawscore
# 3172                                        nih_tlbx_se
# 3173                             rename to version_form
# 3174  strip 'Assessment' from text, and rename to fn...
# 3175                                rename to comqother
# 3176                                                NaN
# 3177                                                NaN
# 3178                             rename to version_form
# 3179  strip 'Assessment' from text, and rename to fn...
# 3180                                rename to comqother
# 3181                                                NaN
# 3182                                                NaN
# 3183                                                NaN
# 3184                             rename to version_form
# 3185  strip 'Assessment' from text, and rename to fn...
# 3186                                rename to comqother
# 3187                                                NaN
# 3188                                                NaN
# 3189                             rename to version_form
# 3190  strip 'Assessment' from text, and rename to fn...
# 3191                                rename to comqother
# 3192                                                NaN
# 3193                                                NaN
#
#                                        requested_python  \
# 0                  studydata['nih_tlbx_rawscore']='999'
# 1                     studydata['nih_tlbx_theta']='999'
# 2                    studydata['nih_tlbx_tscore']='999'
# 3                        studydata['nih_tlbx_se']='999'
# 4                 studydata['nih_tlbx_agegencsc']='999'
# 5           studydata['version_form']=studydata['Inst']
# 6     studydata['fneproc']=studydata['Assessment_Nam...
# 7        studydata['comqother']=studydata['respondent']
# 8     studydata['nih_tlbx_fctsc']=studydata['Fully_C...
# 9     studydata['primary_language']=studydata['Langu...
# 10    studydata['comments1']=studydata['nih_crystalc...
# 11    studydata['comments2']=studydata['nih_eccogcomp']
# 12    studydata['comments3']=studydata['nih_fluidcog...
# 13    studydata['comments4']=studydata['nih_totalcog...
# 14    studydata['interview_language']=studydata['Lan...
# 15    studydata['nih_crycogcomp_ageadjusted']=studyd...
# 16    studydata['nih_crystalcogcomp_np']=studydata['...
# 17    studydata['nih_crycogcomp_unadjusted']=studyda...
# 18    studydata['nih_eccogcomp_ageadjusted']=studyda...
# 19    studydata['nih_earlychildcogcomp_np']=studydat...
# 20                                                  NaN
# 21    studydata.loc[studydata.nih_fluidcogcomp_agead...
# 22    studydata.loc[studydata.nih_fluidcogcomp_np_ag...
# 23    studydata.loc[studydata.nih_fluidcogcomp_unadj...
# 24    studydata['nih_totalcogcomp_ageadjusted']=stud...
# 25    studydata['nih_totalcogcomp_np']=studydata['ni...
# 26                                                  NaN
# 27                          studydata['anger_rs']='999'
# 28                          studydata['anger_ts']='999'
# 29                          studydata['anger_se']='999'
# ...                                                 ...
# 3164        studydata['version_form']=studydata['Inst']
# 3165  studydata['fneproc']=studydata['Assessment_Nam...
# 3166     studydata['comqother']=studydata['respondent']
# 3167  studydata['primary_language']=studydata['Langu...
# 3168   studydata['nih_tlbx_tscore']=studydata['TScore']
# 3169                 studydata['nih_tlbx_tscore']='999'
# 3170                  studydata['nih_tlbx_theta']='999'
# 3171               studydata['nih_tlbx_rawscore']='999'
# 3172                     studydata['nih_tlbx_se']='999'
# 3173        studydata['version_form']=studydata['Inst']
# 3174  studydata['fneproc']=studydata['Assessment_Nam...
# 3175     studydata['comqother']=studydata['respondent']
# 3176  studydata['nih_tlbx_fctsc']=studydata['Fully_C...
# 3177  studydata['primary_language']=studydata['Langu...
# 3178        studydata['version_form']=studydata['Inst']
# 3179  studydata['fneproc']=studydata['Assessment_Nam...
# 3180     studydata['comqother']=studydata['respondent']
# 3181  studydata['nih_tlbx_fctsc']=studydata['Fully_C...
# 3182              studydata['wcst_ni']=studydata.ItmCnt
# 3183  studydata['interview_language']=studydata['Lan...
# 3184        studydata['version_form']=studydata['Inst']
# 3185  studydata['fneproc']=studydata['Assessment_Nam...
# 3186     studydata['comqother']=studydata['respondent']
# 3187  studydata['interview_language']=studydata['Lan...
# 3188     studydata['promisgls_tsc']=studydata['TScore']
# 3189        studydata['version_form']=studydata['Inst']
# 3190  studydata['fneproc']=studydata['Assessment_Nam...
# 3191     studydata['comqother']=studydata['respondent']
# 3192  studydata['nih_tlbx_fctsc']=studydata['Fully_C...
# 3193  studydata['interview_language']=studydata['Lan...
#
#                                          specialty_code  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10    jupyter - there is no Inst so named, but logic...
# 11    jupyter - there is no Inst so named, but logic...
# 12    jupyter - there is no Inst so named, but logic...
# 13    jupyter - there is no Inst so named, but logic...
# 14                                              jupyter
# 15                                              jupyter
# 16                                              jupyter
# 17                                              jupyter
# 18                                              jupyter
# 19                                              jupyter
# 20                                              jupyter
# 21                                              jupyter
# 22                                              jupyter
# 23                                              jupyter
# 24                                              jupyter
# 25                                              jupyter
# 26                                              jupyter
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 3164                                                NaN
# 3165                                                NaN
# 3166                                                NaN
# 3167                                                NaN
# 3168                                                NaN
# 3169                                                NaN
# 3170                                                NaN
# 3171                                                NaN
# 3172                                                NaN
# 3173                                                NaN
# 3174                                                NaN
# 3175                                                NaN
# 3176                                                NaN
# 3177                                                NaN
# 3178                                                NaN
# 3179                                                NaN
# 3180                                                NaN
# 3181                                                NaN
# 3182                                                NaN
# 3183                                                NaN
# 3184                                                NaN
# 3185                                                NaN
# 3186                                                NaN
# 3187                                                NaN
# 3188                                                NaN
# 3189                                                NaN
# 3190                                                NaN
# 3191                                                NaN
# 3192                                                NaN
# 3193                                                NaN
#
#                hcp_variable_upload     nda_structure  \
# 0                nih_tlbx_rawscore    tlbx_fearanx01
# 1                   nih_tlbx_theta    tlbx_fearanx01
# 2                  nih_tlbx_tscore    tlbx_fearanx01
# 3                      nih_tlbx_se    tlbx_fearanx01
# 4               nih_tlbx_agegencsc    tlbx_fearanx01
# 5                     version_form    tlbx_fearanx01
# 6                          fneproc    tlbx_fearanx01
# 7                        comqother    tlbx_fearanx01
# 8                   nih_tlbx_fctsc    tlbx_fearanx01
# 9                 primary_language    tlbx_fearanx01
# 10                       comments1         cogcomp01
# 11                       comments2         cogcomp01
# 12                       comments3         cogcomp01
# 13                       comments4         cogcomp01
# 14              interview_language         cogcomp01
# 15      nih_crycogcomp_ageadjusted         cogcomp01
# 16           nih_crystalcogcomp_np         cogcomp01
# 17       nih_crycogcomp_unadjusted         cogcomp01
# 18       nih_eccogcomp_ageadjusted         cogcomp01
# 19        nih_earlychildcogcomp_np         cogcomp01
# 20        nih_eccogcomp_unadjusted         cogcomp01
# 21    nih_fluidcogcomp_ageadjusted         cogcomp01
# 22             nih_fluidcogcomp_np         cogcomp01
# 23     nih_fluidcogcomp_unadjusted         cogcomp01
# 24    nih_totalcogcomp_ageadjusted         cogcomp01
# 25             nih_totalcogcomp_np         cogcomp01
# 26     nih_totalcogcomp_unadjusted         cogcomp01
# 27                        anger_rs           prang01
# 28                        anger_ts           prang01
# 29                        anger_se           prang01
# ...                            ...               ...
# 3164                  version_form  tlbx_wellbeing01
# 3165                       fneproc  tlbx_wellbeing01
# 3166                     comqother  tlbx_wellbeing01
# 3167              primary_language  tlbx_wellbeing01
# 3168               nih_tlbx_tscore  tlbx_wellbeing01
# 3169               nih_tlbx_tscore  tlbx_wellbeing01
# 3170                nih_tlbx_theta  tlbx_wellbeing01
# 3171             nih_tlbx_rawscore  tlbx_wellbeing01
# 3172                   nih_tlbx_se  tlbx_wellbeing01
# 3173                  version_form  tlbx_wellbeing01
# 3174                       fneproc  tlbx_wellbeing01
# 3175                     comqother  tlbx_wellbeing01
# 3176                nih_tlbx_fctsc  tlbx_wellbeing01
# 3177              primary_language  tlbx_wellbeing01
# 3178                  version_form        promisgl01
# 3179                       fneproc        promisgl01
# 3180                     comqother        promisgl01
# 3181                nih_tlbx_fctsc        promisgl01
# 3182                       wcst_ni        promisgl01
# 3183            interview_language        promisgl01
# 3184                  version_form        promisgl01
# 3185                       fneproc        promisgl01
# 3186                     comqother        promisgl01
# 3187            interview_language        promisgl01
# 3188                 promisgls_tsc        promisgl01
# 3189                  version_form        promisgl01
# 3190                       fneproc        promisgl01
# 3191                     comqother        promisgl01
# 3192                nih_tlbx_fctsc        promisgl01
# 3193            interview_language        promisgl01
#
#                        nda_element  \
# 0                nih_tlbx_rawscore
# 1                   nih_tlbx_theta
# 2                  nih_tlbx_tscore
# 3                      nih_tlbx_se
# 4               nih_tlbx_agegencsc
# 5                     version_form
# 6                          fneproc
# 7                        comqother
# 8                   nih_tlbx_fctsc
# 9                 primary_language
# 10                       comments1
# 11                       comments2
# 12                       comments3
# 13                       comments4
# 14              interview_language
# 15      nih_crycogcomp_ageadjusted
# 16           nih_crystalcogcomp_np
# 17       nih_crycogcomp_unadjusted
# 18       nih_eccogcomp_ageadjusted
# 19        nih_earlychildcogcomp_np
# 20        nih_eccogcomp_unadjusted
# 21    nih_fluidcogcomp_ageadjusted
# 22             nih_fluidcogcomp_np
# 23     nih_fluidcogcomp_unadjusted
# 24    nih_totalcogcomp_ageadjusted
# 25             nih_totalcogcomp_np
# 26     nih_totalcogcomp_unadjusted
# 27                        anger_rs
# 28                        anger_ts
# 29                        anger_se
# ...                            ...
# 3164                  version_form
# 3165                       fneproc
# 3166                     comqother
# 3167              primary_language
# 3168               nih_tlbx_tscore
# 3169               nih_tlbx_tscore
# 3170                nih_tlbx_theta
# 3171             nih_tlbx_rawscore
# 3172                   nih_tlbx_se
# 3173                  version_form
# 3174                       fneproc
# 3175                     comqother
# 3176                nih_tlbx_fctsc
# 3177              primary_language
# 3178                  version_form
# 3179                       fneproc
# 3180                     comqother
# 3181                nih_tlbx_fctsc
# 3182                       wcst_ni
# 3183            interview_language
# 3184                  version_form
# 3185                       fneproc
# 3186                     comqother
# 3187            interview_language
# 3188                 promisgls_tsc
# 3189                  version_form
# 3190                       fneproc
# 3191                     comqother
# 3192                nih_tlbx_fctsc
# 3193            interview_language
#
#                                                template  ...   valueRange  \
# 0                                                   NaN  ...          NaN
# 1                                                   NaN  ...          NaN
# 2                                                   NaN  ...  0::200; 999
# 3                                                   NaN  ...          NaN
# 4                                                   NaN  ...  0::250; 999
# 5                                                   NaN  ...          NaN
# 6                                                   NaN  ...          NaN
# 7                                                   NaN  ...          NaN
# 8           Anxiety_Summary_3-7.tlbx_fearanx01_template  ...       0::120
# 9           Anxiety_Summary_3-7.tlbx_fearanx01_template  ...          NaN
# 10                                                  NaN  ...          NaN
# 11                                                  NaN  ...          NaN
# 12                                                  NaN  ...          NaN
# 13                                                  NaN  ...          NaN
# 14                                   cogcomp01_template  ...          NaN
# 15                                   cogcomp01_template  ...       0::200
# 16                                   cogcomp01_template  ...       0::100
# 17                                   cogcomp01_template  ...       0::200
# 18                                   cogcomp01_template  ...       0::200
# 19                                   cogcomp01_template  ...       0::100
# 20                                   cogcomp01_template  ...       0::200
# 21                                   cogcomp01_template  ...   0::200;999
# 22                                   cogcomp01_template  ...   0::100;999
# 23                                   cogcomp01_template  ...   0::200;999
# 24                                   cogcomp01_template  ...       0::200
# 25                                   cogcomp01_template  ...       0::100
# 26                                   cogcomp01_template  ...       0::200
# 27                                                  NaN  ...          NaN
# 28                                                  NaN  ...          NaN
# 29                                                  NaN  ...          NaN
# ...                                                 ...  ...          ...
# 3164                                                NaN  ...          NaN
# 3165                                                NaN  ...          NaN
# 3166                                                NaN  ...          NaN
# 3167  Well_Being_18+.tlbx_wellbeing01_template.csv/P...  ...          NaN
# 3168  Well_Being_18+.tlbx_wellbeing01_template.csv/P...  ...  0::200; 999
# 3169                                                NaN  ...  0::200; 999
# 3170                                                NaN  ...          NaN
# 3171                                                NaN  ...          NaN
# 3172                                                NaN  ...          NaN
# 3173                                                NaN  ...          NaN
# 3174                                                NaN  ...          NaN
# 3175                                                NaN  ...          NaN
# 3176      Well_Being_8-12.tlbx_wellbeing01_template.csv  ...       0::120
# 3177      Well_Being_8-12.tlbx_wellbeing01_template.csv  ...          NaN
# 3178                                                NaN  ...          NaN
# 3179                                                NaN  ...          NaN
# 3180                                                NaN  ...          NaN
# 3181  Social_Satisfaction_13-17.promisgl01_template.csv  ...       0::120
# 3182  Social_Satisfaction_13-17.promisgl01_template.csv  ...          NaN
# 3183  Social_Satisfaction_13-17.promisgl01_template.csv  ...          NaN
# 3184  Social_Satisfaction_13-17.promisgl01_template....  ...          NaN
# 3185                                                NaN  ...          NaN
# 3186                                                NaN  ...          NaN
# 3187  Social_Satisfaction_13-17.promisgl01_template....  ...          NaN
# 3188  Social_Satisfaction_13-17.promisgl01_template....  ...          NaN
# 3189                                                NaN  ...          NaN
# 3190                                                NaN  ...          NaN
# 3191                                                NaN  ...          NaN
# 3192   Social_Satisfaction_8-12.promisgl01_template.csv  ...       0::120
# 3193   Social_Satisfaction_8-12.promisgl01_template.csv  ...          NaN
#
#                                                   notes  \
# 0                                                   NaN
# 1                                     999=NA/NK/missing
# 2                                     999=NA/NK/missing
# 3                                     999=NA/NK/missing
# 4                                     999=NA/NK/missing
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21    composite score is derived by averaging the no...
# 22    National percentile of composite score that is...
# 23    composite score is derived by averaging the no...
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 3164                                                NaN
# 3165                                                NaN
# 3166                                                NaN
# 3167                                                NaN
# 3168                                  999=NA/NK/missing
# 3169                                  999=NA/NK/missing
# 3170                                  999=NA/NK/missing
# 3171                                                NaN
# 3172                                  999=NA/NK/missing
# 3173                                                NaN
# 3174                                                NaN
# 3175                                                NaN
# 3176                                                NaN
# 3177                                                NaN
# 3178                                                NaN
# 3179                                                NaN
# 3180                                                NaN
# 3181                                                NaN
# 3182                                                NaN
# 3183                                                NaN
# 3184                                                NaN
# 3185                                                NaN
# 3186                                                NaN
# 3187                                                NaN
# 3188                                                NaN
# 3189                                                NaN
# 3190                                                NaN
# 3191                                                NaN
# 3192                                                NaN
# 3193                                                NaN
#
#                                      nda_structure_link Measurement System  \
# 0     https://nda.nih.gov/data_structure.html?short_...                NaN
# 1     https://nda.nih.gov/data_structure.html?short_...                NaN
# 2     https://nda.nih.gov/data_structure.html?short_...                NaN
# 3     https://nda.nih.gov/data_structure.html?short_...                NaN
# 4     https://nda.nih.gov/data_structure.html?short_...                NaN
# 5     https://nda.nih.gov/data_structure.html?short_...                NaN
# 6     https://nda.nih.gov/data_structure.html?short_...                NaN
# 7     https://nda.nih.gov/data_structure.html?short_...                NaN
# 8     https://nda.nih.gov/data_structure.html?short_...                NaN
# 9     https://nda.nih.gov/data_structure.html?short_...                NaN
# 10    https://nda.nih.gov/data_structure.html?short_...                NaN
# 11    https://nda.nih.gov/data_structure.html?short_...                NaN
# 12    https://nda.nih.gov/data_structure.html?short_...                NaN
# 13    https://nda.nih.gov/data_structure.html?short_...                NaN
# 14    https://nda.nih.gov/data_structure.html?short_...                NaN
# 15    https://nda.nih.gov/data_structure.html?short_...                NaN
# 16    https://nda.nih.gov/data_structure.html?short_...                NaN
# 17    https://nda.nih.gov/data_structure.html?short_...                NaN
# 18    https://nda.nih.gov/data_structure.html?short_...                NaN
# 19    https://nda.nih.gov/data_structure.html?short_...                NaN
# 20    https://nda.nih.gov/data_structure.html?short_...                NaN
# 21    https://nda.nih.gov/data_structure.html?short_...                NaN
# 22    https://nda.nih.gov/data_structure.html?short_...                NaN
# 23    https://nda.nih.gov/data_structure.html?short_...                NaN
# 24    https://nda.nih.gov/data_structure.html?short_...                NaN
# 25    https://nda.nih.gov/data_structure.html?short_...                NaN
# 26    https://nda.nih.gov/data_structure.html?short_...                NaN
# 27    https://nda.nih.gov/data_structure.html?short_...                NaN
# 28    https://nda.nih.gov/data_structure.html?short_...                NaN
# 29    https://nda.nih.gov/data_structure.html?short_...                NaN
# ...                                                 ...                ...
# 3164  https://nda.nih.gov/data_structure.html?short_...                NaN
# 3165  https://nda.nih.gov/data_structure.html?short_...                NaN
# 3166  https://nda.nih.gov/data_structure.html?short_...                NaN
# 3167  https://nda.nih.gov/data_structure.html?short_...                NaN
# 3168  https://nda.nih.gov/data_structure.html?short_...                NaN
# 3169  https://nda.nih.gov/data_structure.html?short_...                NaN
# 3170  https://nda.nih.gov/data_structure.html?short_...                NaN
# 3171  https://nda.nih.gov/data_structure.html?short_...                NaN
# 3172  https://nda.nih.gov/data_structure.html?short_...                NaN
# 3173  https://nda.nih.gov/data_structure.html?short_...                NaN
# 3174  https://nda.nih.gov/data_structure.html?short_...                NaN
# 3175  https://nda.nih.gov/data_structure.html?short_...                NaN
# 3176  https://nda.nih.gov/data_structure.html?short_...                NaN
# 3177  https://nda.nih.gov/data_structure.html?short_...                NaN
# 3178  https://nda.nih.gov/data_structure.html?short_...                NaN
# 3179  https://nda.nih.gov/data_structure.html?short_...                NaN
# 3180  https://nda.nih.gov/data_structure.html?short_...                NaN
# 3181  https://nda.nih.gov/data_structure.html?short_...                NaN
# 3182  https://nda.nih.gov/data_structure.html?short_...                NaN
# 3183  https://nda.nih.gov/data_structure.html?short_...                NaN
# 3184  https://nda.nih.gov/data_structure.html?short_...                NaN
# 3185  https://nda.nih.gov/data_structure.html?short_...                NaN
# 3186  https://nda.nih.gov/data_structure.html?short_...                NaN
# 3187  https://nda.nih.gov/data_structure.html?short_...                NaN
# 3188  https://nda.nih.gov/data_structure.html?short_...                NaN
# 3189  https://nda.nih.gov/data_structure.html?short_...                NaN
# 3190  https://nda.nih.gov/data_structure.html?short_...                NaN
# 3191  https://nda.nih.gov/data_structure.html?short_...                NaN
# 3192  https://nda.nih.gov/data_structure.html?short_...                NaN
# 3193  https://nda.nih.gov/data_structure.html?short_...                NaN
#
#      Domain Item ID Stem Context DataType Responses
# 0       NaN     NaN  NaN     NaN      NaN       NaN
# 1       NaN     NaN  NaN     NaN      NaN       NaN
# 2       NaN     NaN  NaN     NaN      NaN       NaN
# 3       NaN     NaN  NaN     NaN      NaN       NaN
# 4       NaN     NaN  NaN     NaN      NaN       NaN
# 5       NaN     NaN  NaN     NaN      NaN       NaN
# 6       NaN     NaN  NaN     NaN      NaN       NaN
# 7       NaN     NaN  NaN     NaN      NaN       NaN
# 8       NaN     NaN  NaN     NaN      NaN       NaN
# 9       NaN     NaN  NaN     NaN      NaN       NaN
# 10      NaN     NaN  NaN     NaN      NaN       NaN
# 11      NaN     NaN  NaN     NaN      NaN       NaN
# 12      NaN     NaN  NaN     NaN      NaN       NaN
# 13      NaN     NaN  NaN     NaN      NaN       NaN
# 14      NaN     NaN  NaN     NaN      NaN       NaN
# 15      NaN     NaN  NaN     NaN      NaN       NaN
# 16      NaN     NaN  NaN     NaN      NaN       NaN
# 17      NaN     NaN  NaN     NaN      NaN       NaN
# 18      NaN     NaN  NaN     NaN      NaN       NaN
# 19      NaN     NaN  NaN     NaN      NaN       NaN
# 20      NaN     NaN  NaN     NaN      NaN       NaN
# 21      NaN     NaN  NaN     NaN      NaN       NaN
# 22      NaN     NaN  NaN     NaN      NaN       NaN
# 23      NaN     NaN  NaN     NaN      NaN       NaN
# 24      NaN     NaN  NaN     NaN      NaN       NaN
# 25      NaN     NaN  NaN     NaN      NaN       NaN
# 26      NaN     NaN  NaN     NaN      NaN       NaN
# 27      NaN     NaN  NaN     NaN      NaN       NaN
# 28      NaN     NaN  NaN     NaN      NaN       NaN
# 29      NaN     NaN  NaN     NaN      NaN       NaN
# ...     ...     ...  ...     ...      ...       ...
# 3164    NaN     NaN  NaN     NaN      NaN       NaN
# 3165    NaN     NaN  NaN     NaN      NaN       NaN
# 3166    NaN     NaN  NaN     NaN      NaN       NaN
# 3167    NaN     NaN  NaN     NaN      NaN       NaN
# 3168    NaN     NaN  NaN     NaN      NaN       NaN
# 3169    NaN     NaN  NaN     NaN      NaN       NaN
# 3170    NaN     NaN  NaN     NaN      NaN       NaN
# 3171    NaN     NaN  NaN     NaN      NaN       NaN
# 3172    NaN     NaN  NaN     NaN      NaN       NaN
# 3173    NaN     NaN  NaN     NaN      NaN       NaN
# 3174    NaN     NaN  NaN     NaN      NaN       NaN
# 3175    NaN     NaN  NaN     NaN      NaN       NaN
# 3176    NaN     NaN  NaN     NaN      NaN       NaN
# 3177    NaN     NaN  NaN     NaN      NaN       NaN
# 3178    NaN     NaN  NaN     NaN      NaN       NaN
# 3179    NaN     NaN  NaN     NaN      NaN       NaN
# 3180    NaN     NaN  NaN     NaN      NaN       NaN
# 3181    NaN     NaN  NaN     NaN      NaN       NaN
# 3182    NaN     NaN  NaN     NaN      NaN       NaN
# 3183    NaN     NaN  NaN     NaN      NaN       NaN
# 3184    NaN     NaN  NaN     NaN      NaN       NaN
# 3185    NaN     NaN  NaN     NaN      NaN       NaN
# 3186    NaN     NaN  NaN     NaN      NaN       NaN
# 3187    NaN     NaN  NaN     NaN      NaN       NaN
# 3188    NaN     NaN  NaN     NaN      NaN       NaN
# 3189    NaN     NaN  NaN     NaN      NaN       NaN
# 3190    NaN     NaN  NaN     NaN      NaN       NaN
# 3191    NaN     NaN  NaN     NaN      NaN       NaN
# 3192    NaN     NaN  NaN     NaN      NaN       NaN
# 3193    NaN     NaN  NaN     NaN      NaN       NaN
#
# [3194 rows x 23 columns]

# %%
newcrosswalk.columns
# Out:
# Index(['validated', 'Inst', 'hcp_variable', 'action_requested',
#        'requested_python', 'specialty_code', 'hcp_variable_upload',
#        'nda_structure', 'nda_element', 'template', 'inst_short', 'Source',
#        'description', 'valueRange', 'notes', 'nda_structure_link',
#        'Measurement System', 'Domain', 'Item ID', 'Stem', 'Context',
#        'DataType', 'Responses'],
#       dtype='object')

# %%
newcrosswalk.shape
#crosswalk.shape
# Out:
# (3194, 23)

# %%
newcrosswalk.to_csv(pathin+crosswalkfile,index=False)
